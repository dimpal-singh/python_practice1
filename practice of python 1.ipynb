# %%
1_massage = [1,2,3,4]

# %%
mesage = "Hello python crash course reader!"
print(mesage)
# Out:
# Hello python crash course reader!

# %%
name = "ada lovelace"
print(name.title())
# Out:
# Ada Lovelace

# %%
print(name.upper())
# Out:
# ADA LOVELACE

# %%
print(name.lower())
# Out:
# ada lovelace

# %%
first_name = "adda"
last_name = "lowercase"
full_name = f"{first_name} {last_name}"
print(print(full_name))
# Out:
# adda lowercase
# None

# %%
string1 = "Hello"
string2 = string1 + "World"
print(string1)
print(string2)
# Out:
# Hello
# HelloWorld

# %%
first_name = "adda"
last_name = "lowercase"
full_name_name = f"{first_name} (last_name)"
print(f"Hello, {full_name.title()}!")
# Out:
# Hello, Adda Lowercase!

# %%
first_name = "adda"
last_name = "lowercase"
full_name_name = f"{first_name} (last_name)"
message = (f"Hello, {full_name.title()}!")
print(message)
# Out:
# Hello, Adda Lowercase!

# %%
print("python")
# Out:
# python

# %%
print("\tpython")
# Out:
# 	python

# %%
print("languages:\npython\nC\njavaScript")
# Out:
# languages:
# python
# C
# javaScript

# %%
favorite_language = 'python '
favorite_language
# Out:
# 'python '

# %%
favorite_language.rstrip()
# Out:
# 'python'

# %%
favorite_language
# Out:
# 'python '

# %%
favorite_language =' python '

# %%
favorite_language.rstrip()
# Out:
# ' python'

# %%
favorite_language.lstrip()
# Out:
# 'python '

# %%
favorite_language.strip()
# Out:
# 'python'

# %%
nostarch_url = 'https://nostarch.com'
nostarch_url.removeprefix('https://')
'nostarch.com'
# Out:
# 'nostarch.com'

# %%
2 + 3*2
# Out:
# 8

# %%
(2 + 3 ) * 2
# Out:
# 10

# %%
0.1+0.1
# Out:
# 0.2

# %%
0.2+0.2
# Out:
# 0.4

# %%
2 * 0.1
# Out:
# 0.2

# %%
2 * 0.2
# Out:
# 0.4

# %%
0.2+0.1
# Out:
# 0.30000000000000004

# %%
3*0.1
# Out:
# 0.30000000000000004

# %%
x,y,z = 0,0,0

# %%
x
# Out:
# 0
